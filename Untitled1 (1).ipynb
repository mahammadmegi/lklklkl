# %% [markdown]
# Number 16

# %%
import math
n1 = ((math.log(5, 2)*math.sqrt(5))-(5**(1/3))*math.log(5, 3))/(1-0.1845*(math.sin(1) + 2*math.cos(1)))
def ctg(x):
    return 1 / math.tan(x)
n2 = math.exp(-2)*ctg((1/2)*math.cos(-4/7))
if n1*n2<0.1:
  s = math.sqrt(abs(n1*n2))
else:
  s = math.sqrt(abs(n1+n2))
print(s)
# Out:
# 2.1132740731261777

# %% [markdown]
# Number 15

# %%
import math
m1=(3.78*((math.e)**4-(math.e)**3))/(4**(1/3)+3**(1/5))
m2=math.log(3)*math.sin(math.sin(-2*(2**(1/2))/3)/2)
m3=(m1-2*m2)/(m1**(1/2)+2)
m4=2/(m1-2*m2)
if abs(m1 -2*m2)<=1:
    print(m3)
else:
    print(m4)
# Out:
# 0.04263291503895966

# %% [markdown]
# Number 1

# %%
import math
a=float(0.75*(0.5)**(1/2)-(1/2)*(4**(1/3)))
b=float(100**(1/2*math.log(9)-math.log(2))*math.tan(1/3))
if a>b:
  k=(15*a**2+21*b**2)**(1/2)
else:
  k=(15*b**2+21*a**2)**(1/2)
print(k)
# Out:
# 8.76054450539713

# %% [markdown]
# Number 3

# %%
import math
k=float(86.9**(-1/4)+(2**1/float(0.3))**(1/3))
m=49**(1-math.log10(2))+5**(-math.log10(4))
print(k,m)
# Out:
# 2.2095975106883623 15.563826035415337
